# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('/content/pizza_sales.csv')

# %%
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0           1.0       1.0     hawaiian_m       1.0    1/1/2015   11:38:36
# 1           2.0       2.0  classic_dlx_m       1.0    1/1/2015   11:57:40
# 2           3.0       2.0  five_cheese_l       1.0    1/1/2015   11:57:40
# 3           4.0       2.0    ital_supr_l       1.0    1/1/2015   11:57:40
# 4           5.0       2.0     mexicana_m       1.0    1/1/2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615   48616.0   21348.0  ckn_alfredo_m       1.0  31-12-2015   21:23:10
# 48616   48617.0   21348.0  four_cheese_l       1.0  31-12-2015   21:23:10
# 48617   48618.0   21348.0   napolitana_s       1.0  31-12-2015   21:23:10
# 48618   48619.0   21349.0     mexicana_l       1.0  31-12-2015   22:09:54
# 48619   48620.0   21350.0      bbq_ckn_s       1.0  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.head()
# Out:
#   pizza_id order_id  pizza_name_id  quantity order_date order_time unit_price  \
# 0     1.00     1.00     hawaiian_m       1.0   1/1/2015   11:38:36      13.25
# 1     2.00     2.00  classic_dlx_m       1.0   1/1/2015   11:57:40      16.00
# 2     3.00     2.00  five_cheese_l       1.0   1/1/2015   11:57:40      18.50
# 3     4.00     2.00    ital_supr_l       1.0   1/1/2015   11:57:40      20.75
# 4     5.00     2.00     mexicana_m       1.0   1/1/2015   11:57:40      16.00
#
#   total_price pizza_size pizza_category  \
# 0       13.25          M        Classic
# 1          16          M        Classic
# 2        18.5          L         Veggie
# 3       20.75          L        Supreme
# 4          16          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# ...

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60511 entries, 0 to 60510
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           60511 non-null  object
#  1   order_id           60511 non-null  object
#  2   pizza_name_id      60511 non-null  object
#  3   quantity           60511 non-null  float64
#  4   order_date         60511 non-null  object
#  5   order_time         60511 non-null  object
#  6   unit_price         60510 non-null  object
#  7   total_price        60510 non-null  object
#  8   pizza_size         60509 non-null  object
#  9   pizza_category     60509 non-null  object
#  10  pizza_ingredients  60509 non-null  object
#  11  pizza_name         60509 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 5.5+ MB

# %%
df.describe()
# Out:
#            quantity
# count  60511.000000
# mean       1.020108
# std        0.164559
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       20.750000

# %%
 df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           1
# total_price          1
# pizza_size           2
# pizza_category       2
# pizza_ingredients    2
# pizza_name           2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(11889)

# %%
total_sales_per_order = df.groupby('order_id')['total_price'].sum()

# %%
total_sales_per_order
# Out:
# order_id
# 1.00                                                    13.25
# 10.00                                              20.2520.75
# 100.00                                                   16.5
# 1000.00                                            23.6520.25
# 10000.00                                       20.7520.2517.5
#                                   ...
# 9995.00                                                 13.25
# 9996.00                                                 23.65
# 9997.00     12.7517.9516.513.2510.520.7520.2517.520.7512.5...
# 9998.00                                       16.7512.7520.75
# 9999.00                                             20.512.25
# Name: total_price, Length: 21351, dtype: object

# %%
df['order_date']= pd.to_datetime(df['order_date'], errors='coerce')

# %%
df['order_date']=df['order_date'].dt.strftime('%d-%m-%y')

# %%
df['order_dt']=pd.to_datetime(df['order_date'])
# Out:
# <ipython-input-14-467a6bb26538>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_dt']=pd.to_datetime(df['order_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  float64
#  1   order_id           48620 non-null  float64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  float64
#  4   order_date         19587 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
#  12  order_dt           19587 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 4.8+ MB

# %%
df['Year'] = df['order_dt'].dt.year

# %%
df['Month'] = df['order_dt'].dt.month_name()

# %%
df['Day'] = df['order_dt'].dt.day_name()

# %%
df.head(5)
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0       1.0       1.0     hawaiian_m       1.0   01-01-15   11:38:36
# 1       2.0       2.0  classic_dlx_m       1.0   01-01-15   11:57:40
# 2       3.0       2.0  five_cheese_l       1.0   01-01-15   11:57:40
# 3       4.0       2.0    ital_supr_l       1.0   01-01-15   11:57:40
# 4       5.0       2.0     mexicana_m       1.0   01-01-15   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# ...

# %%
df['Month'].unique()
# Out:
# array(['January', nan, 'February', 'March', 'April', 'May', 'June',
#        'July', 'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=df, x="Month")
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
sns.countplot(data=df, x="Day")
# Out:
# <Axes: xlabel='Day', ylabel='count'>

# %% [markdown]
# Total Orders
# Revenue
# Highest priced pizza
# Most common pizza slice ordered

# %%
df['total_price'].sum()
# Out:
# np.float64(817860.05)

# %%
df['order_id'].nunique()
# Out:
# 21350

# %%
#HW1

least_ordered_pizzas = df.groupby('pizza_name')['quantity'].sum().sort_values(ascending=True).head(5)
print("5 least ordered pizza types:")
least_ordered_pizzas
# Out:
# 5 least ordered pizza types:
# pizza_name
# The Brie Carre Pizza         490.0
# The Mediterranean Pizza      934.0
# The Calabrese Pizza          937.0
# The Spinach Supreme Pizza    950.0
# The Soppressata Pizza        961.0
# Name: quantity, dtype: float64

# %%
# prompt: Determine the top 3 most ordered pizza types based on revenue

top_pizza_by_revenue = df.groupby('pizza_name')['total_price'].sum().sort_values(ascending=False).head(3)

print("Top 3 most ordered pizza types based on revenue:")
top_pizza_by_revenue
# Out:
# Top 3 most ordered pizza types based on revenue:
# pizza_name
# The Thai Chicken Pizza          43434.25
# The Barbecue Chicken Pizza      42768.00
# The California Chicken Pizza    41409.50
# Name: total_price, dtype: float64

# %%
import pandas as pd
import numpy as np

# %%
least_pizza_by_revenue = df.groupby('pizza_name')['total_price'].sum().sort_values(ascending=True).head(3)
print("3 least ordered pizza types based on revenue:")
least_pizza_by_revenue
# Out:
# 3 least ordered pizza types based on revenue:
# pizza_name
# The Brie Carre Pizza         11588.50
# The Green Garden Pizza       13955.75
# The Spinach Supreme Pizza    15277.75
# Name: total_price, dtype: float64

# %%
# prompt: draw a histogram of quantity and pizza name

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
sns.barplot(x='pizza_name', y='quantity', data=df.groupby('pizza_name')['quantity'].sum().reset_index().sort_values(by='quantity', ascending=False))
plt.xticks(rotation=90)
plt.title('Total Quantity Ordered per Pizza Name')
plt.xlabel('Pizza Name')
plt.ylabel('Total Quantity Ordered')
plt.tight_layout()
plt.show()

# %%
# prompt: make a count graph for pizza category

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="pizza_category")
plt.title('Count of Pizzas by Category')
plt.xlabel('Pizza Category')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
df3= pd.read_csv('/content/Details.csv')

# %%
df2 =pd.read_csv('/content/Orders.csv')

# %%
df3.describe()
# Out:
#             Amount      Profit     Quantity
# count  1500.000000  1500.00000  1500.000000
# mean    291.847333    24.64200     3.743333
# std     461.924620   168.55881     2.184942
# min       4.000000 -1981.00000     1.000000
# 25%      47.750000   -12.00000     2.000000
# 50%     122.000000     8.00000     3.000000
# 75%     326.250000    38.00000     5.000000
# max    5729.000000  1864.00000    14.000000

# %%
df2.describe()
# Out:
#        Order ID  Order Date CustomerName        State    City
# count       500         500          500          500     500
# unique      500         307          336           19      25
# top     B-26095  24-11-2018       Shreya  Maharashtra  Indore
# freq          1           7            6           94      71

# %%
df3
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
df2
# Out:
#     Order ID  Order Date CustomerName             State     City
# 0    B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura
# 1    B-25993  03-02-2018       Madhav             Delhi    Delhi
# 2    B-25973  24-01-2018  Madan Mohan     Uttar Pradesh  Mathura
# 3    B-25923  27-12-2018        Gopal       Maharashtra   Mumbai
# 4    B-25757  21-08-2018     Vishakha    Madhya Pradesh   Indore
# ..       ...         ...          ...               ...      ...
# 495  B-25742  03-08-2018       Ashwin               Goa      Goa
# 496  B-26088  26-03-2018       Bhavna            Sikkim  Gangtok
# 497  B-25707  01-07-2018      Shivani       Maharashtra   Mumbai
# 498  B-25758  22-08-2018      Shubham  Himachal Pradesh    Simla
# 499  B-26095  28-03-2018      Monisha         Rajasthan   Jaipur
#
# [500 rows x 5 columns]

# %%
# prompt: count category wise

df3['Category'].value_counts()
# Out:
# Category
# Clothing       949
# Electronics    308
# Furniture      243
# Name: count, dtype: int64

# %%
df3.groupby('Sub-Category')['Quantity'].mean()
# Out:
# Sub-Category
# Accessories         3.638889
# Bookcases           3.759494
# Chairs              3.743243
# Electronic Games    3.759494
# Furnishings         4.246575
# Hankerchief         3.761421
# Kurti               3.489362
# Leggings            3.509434
# Phones              3.662651
# Printers            3.932432
# Saree               3.767773
# Shirt               3.927536
# Skirt               3.875000
# Stole               3.494792
# T-shirt             3.961039
# Tables              3.588235
# Trousers            3.461538
# Name: Quantity, dtype: float64

# %%
merged_df
# Out:
#      Order ID  Order Date CustomerName             State     City  Amount  \
# 0     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura    5729
# 1     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura     671
# 2     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura     443
# 3     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura      57
# 4     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura     227
# ...       ...         ...          ...               ...      ...     ...
# 1495  B-25742  03-08-2018       Ashwin               Goa      Goa      11
# 1496  B-26088  26-03-2018       Bhavna            Sikkim  Gangtok      11
# 1497  B-25707  01-07-2018      Shivani       Maharashtra   Mumbai       8
# 1498  B-25758  22-08-2018      Shubham  Himachal Pradesh    Simla       8
# 1499  B-26095  28-03-2018      Monisha         Rajasthan   Jaipur       6
#
#       Profit  Quantity     Category Sub-Category  PaymentMode
# ...
